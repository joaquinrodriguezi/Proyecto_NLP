# %% [markdown]
# # Modelado y evaluación del clasificador
#
# **Objetivo:** Entrenar un clasificador de texto con PyTorch sobre las características TF-IDF y reportar métricas de validación y test.
#
# **Fecha:** 2026-07-04
#
# **Autor:** Copilot

# %% [markdown]
# ## Índice
#
# 1. Qué hace el script
# 2. Funciones y clases clave
# 3. Gráficos y artefactos
# 4. Ejemplo reducido
# 5. Cómo reproducir
# 6. Resumen de artefactos

# %% [markdown]
# ## Qué hace el script
#
# El script define TextClassifier con capas densas, BatchNorm y Dropout, usa Adam, CrossEntropyLoss con class weights y early stopping. Guarda checkpoints, historial de entrenamiento, reportes y ejemplos mal clasificados para interpretar el comportamiento del modelo.

# %% [markdown]
# ## Funciones y clases usadas
#
# - **TextClassifier**
# - **SparseRowDataset**
# - **evaluate_model**
# - **plot_confusion_matrix**

# %% [markdown]
# ## Gráficos y artefactos
#
# - Se guarda artifacts/best_model.pt.
# - Se genera artifacts/training_history.csv.
# - Se crea artifacts/confusion_matrix.png y artifacts/misclassified_examples.csv.

# %% [markdown]
# ## Ejemplo reducido: cargar historial si existe

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
ARTIFACTS_DIR = PROJECT_ROOT / 'artifacts'
path = ARTIFACTS_DIR / 'training_history.csv'
if path.exists():
    history = pd.read_csv(path)
    print(history[['epoch', 'train_loss', 'val_loss', 'val_acc', 'val_f1_macro']].head(10).to_string(index=False))
else:
    print('training_history.csv aún no está disponible; el script completo lo generará.')
# Out:
#  epoch  train_loss  val_loss  val_acc  val_f1_macro
#      1    0.582207  0.511076 0.805333      0.757891
#      2    0.308178  0.383372 0.845333      0.833236
#      3    0.203372  0.417904 0.821333      0.808803
#      4    0.139481  0.475717 0.840000      0.825235
#      5    0.110795  0.520038 0.824000      0.809639
#      6    0.087493  0.648244 0.824000      0.807758
#      7    0.077458  0.736517 0.802667      0.788517

# %% [markdown]
# ## Ejemplo reducido: cargar ejemplos mal clasificados

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
ARTIFACTS_DIR = PROJECT_ROOT / 'artifacts'
path = ARTIFACTS_DIR / 'misclassified_examples.csv'
if path.exists():
    mis = pd.read_csv(path)
    print(mis.head(10).to_string(index=False))
else:
    print('No hay misclassified_examples.csv aún')
# Out:
#  id                                                                                             text_lemma  true_label  pred_label  pred_prob
# 115                                                                                             honest say           1           0   0.999882
# 304 return to the pondemoji_face_with_tears_of_joyemoji_face_with_tears_of_joyemoji_face_with_tears_of_joy           1           0   0.982479
#  35                                                                                               bless he           0           1   0.980472
# 287                                                                         jon jones vs jake paul confirm           0           1   0.978296
# 119              lol guru jon be not fight ngannou he s not fight anyone he s the wwe heavyweight champion           0           1   0.977711
# ...

# %% [markdown]
# ## Cómo reproducir
#
# python src/train.py

# %% [markdown]
# Este notebook se apoya en los artefactos de vectorización y produce los resultados que luego se analizan en el notebook de gráficos.

# %%
from pathlib import Path
from datetime import datetime

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
ARTIFACTS_DIR = PROJECT_ROOT / 'artifacts'
ARTIFACTS_DIR.mkdir(exist_ok=True)
print('Resumen del notebook')
print('- notebook:', Path.cwd().name)
print('- artefactos disponibles:', len(list(ARTIFACTS_DIR.glob('*'))))
print('- timestamp:', datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# Resumen del notebook
# - notebook: notebooks
# - artefactos disponibles: 66
# - timestamp: 2026-07-07 21:32:28
